# %%
import pandas as pd
import numpy as np

# %%
#Read the csv file into a DataFrame
shark_attack = pd.read_csv('C:\\Users\\Matheus Zavagli\\Projeto-Shark-Attack\\attacks.csv', sep=',', encoding = 'latin1')

# %%
before = shark_attack.shape
before
# Out:
# (25723, 24)

# %%
shark_attack.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %%
shark_attack.info()
#Muitos objetos com valores nulos e a coluna "Ano e Age", deveriam ser um inteiro e não um objeto.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# # Pretendo trabalhar em ataques de tubarão por continente e ver se os ataques estão associados a morte.

# %%
#Checar o nome das colunas disponíveis.
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#Drop nas colunas que não serão utilizadas na análise.
shark_attack = shark_attack.drop(columns = ['Unnamed: 22', 'Unnamed: 23','pdf','href formula','href','original order','Investigator or Source','Name','Case Number.1','Case Number.2'])

# %%
#Checar se as colunas foram dropadas.
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species '],
#       dtype='object')

# %%
#Usar o drop_duplicates para saber se há valores duplicados.
after = shark_attack.drop_duplicates().shape
print("Valores antes:", before,"Valores depois:",after)
#Podemos analisar que havia um grande número de valores duplicados.
# Out:
# Valores antes: (25723, 24) Valores depois: (6305, 14)

# %%
#Checar quantos valores nulos temos em cada coluna.
null_cols = shark_attack.isnull().sum()
null_cols
#Notamos que grande parte dos valores atribuidos são nulos. Podendo ser dados onde não foi possivel coletar as informações ou uma pré tabela vazia onde os valores são adicionados conforme a ocorrência.
# Out:
# Case Number    17021
# Date           19421
# Year           19423
# Type           19425
# Country        19471
# Area           19876
# Location       19961
# Activity       19965
# Sex            19986
# Age            22252
# Injury         19449
# Fatal (Y/N)    19960
# Time           22775
# Species        22259
# dtype: int64

# %% [markdown]
# Arrumando valores inválidos e nulos.

# %%
# Para evitar uma grande quantidade de dados perdidos e dados de baixa qualidade, escolheremos selecionar os dados de 1800 até os dias atuais 
shark_attack = shark_attack[shark_attack["Year"] >= 1800]
shark_attack
# Out:
#        Case Number                  Date    Year          Type     Country  \
# 0       2018.06.25           25-Jun-2018  2018.0       Boating         USA
# 1       2018.06.18           18-Jun-2018  2018.0    Unprovoked         USA
# 2       2018.06.09           09-Jun-2018  2018.0       Invalid         USA
# 3       2018.06.08           08-Jun-2018  2018.0    Unprovoked   AUSTRALIA
# 4       2018.06.04           04-Jun-2018  2018.0      Provoked      MEXICO
# ...            ...                   ...     ...           ...         ...
# 6128    1803.05.17           May-17-1803  1803.0  Sea Disaster         USA
# 6129    1803.03.00              Mar-1803  1803.0    Unprovoked   AUSTRALIA
# 6130  1802.04.13.R  Reported Apr-13-1802  1802.0    Unprovoked       INDIA
# 6131  1801.12.18.R  Reported 18-Dec-1801  1801.0      Provoked         NaN
# 6132    1800.00.00                  1800  1800.0    Unprovoked  SEYCHELLES
#
#                    Area                          Location  \
# ...

# %% [markdown]
# # Limpando a coluna Fatal(Y/N)

# %%
# Alteração dos valores que estão diferentes, para um único padrão na coluna Fatal (Y/N)
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].str.replace(" N","N")
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].str.replace("N ","N")
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].str.replace("y","Y")
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].str.replace("M","UNKNOWN")
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].str.replace("2017","UNKNOWN")

# %%
#Substituição dos valores NaN em Fatal (Y/N) por UNKNOWN.
shark_attack["Fatal (Y/N)"] = shark_attack["Fatal (Y/N)"].fillna("UNKNOWN")

# %%
#Check se a função foi aplicada.
shark_attack["Fatal (Y/N)"].value_counts()
# Out:
# N          4230
# Y          1303
# UNKNOWN     598
# Name: Fatal (Y/N), dtype: int64

# %% [markdown]
# # Limpando a coluna Country

# %%
#Entendimento dos casos núlos na categoria Country.
null_display2 = shark_attack[shark_attack['Country'].isnull() == True]
null_display2
#Aparentemente são dados onde não foi possível coletar a informação.
# Out:
#          Case Number                  Date    Year          Type Country  \
# 62      2017.11.13.R  Reported 13-Nov-2017  2017.0    Unprovoked     NaN
# 525       2014.08.00              Aug-2014  2014.0       Invalid     NaN
# 2956    1983.00.00.d              Ca. 1983  1983.0    Unprovoked     NaN
# 3378      1970.11.00              Nov-1970  1970.0    Unprovoked     NaN
# 3387      1970.08.02           02-Aug-1970  1970.0       Invalid     NaN
# 3388      1970.07.05            5-Jul-1970  1970.0    Unprovoked     NaN
# 3395    1970.04.00.b              Apr-1970  1970.0      Provoked     NaN
# 3399      1970.02.05            5-Feb-1970  1970.0    Unprovoked     NaN
# 3425      1969.08.00              Aug-1969  1969.0    Unprovoked     NaN
# 3605      1965.10.21           21-Oct-1965  1965.0    Unprovoked     NaN
# 3661      1964.09.27           27-Sep-1964  1964.0       Invalid     NaN
# 4018      1960.01.26           26-Jan-1960  1960.0  Sea Disaster     NaN
# ...

# %%
#Substituição dos valores NaN em Country por UNKNOWN.
shark_attack["Country"] = shark_attack["Country"].fillna("UNKNOWN")

# %%
#Coloquei em ordem ascendente para ver o resultado
shark_attack = shark_attack.sort_values("Country", ascending = True)
display(shark_attack["Country"])
# Out:
# 4636          PHILIPPINES
# 2035                TONGA
# 1679                TONGA
# 1678                TONGA
# 3786    ADMIRALTY ISLANDS
#               ...
# 5473               YEMEN
# 5611               YEMEN
# 5603               YEMEN
# 5547               YEMEN
# 5591               YEMEN
# Name: Country, Length: 6131, dtype: object

# %%
#No passo anterior, obtive paises que começam com " ", usando o strip removeremos esse " ".
shark_attack['Country'] = shark_attack['Country'].str.strip()
#Check se a condição foi aplicada.
shark_attack = shark_attack.sort_values("Country", ascending = True)
display(shark_attack["Country"])
# Out:
# 3786    ADMIRALTY ISLANDS
# 6049               AFRICA
# 6058              ALGERIA
# 4286       AMERICAN SAMOA
# 4131       AMERICAN SAMOA
#               ...
# 5473                YEMEN
# 5611                YEMEN
# 5603                YEMEN
# 5547                YEMEN
# 5591                YEMEN
# Name: Country, Length: 6131, dtype: object

# %%
#Utilizamos o unique para ver todos os países e possamos trabalhar de maneira padronizada.
shark_attack['Country'].unique()
# Out:
# array(['ADMIRALTY ISLANDS', 'AFRICA', 'ALGERIA', 'AMERICAN SAMOA',
#        'ANDAMAN / NICOBAR ISLANDAS', 'ANDAMAN ISLANDS', 'ANGOLA',
#        'ANTIGUA', 'ARGENTINA', 'ARUBA', 'ATLANTIC OCEAN', 'AUSTRALIA',
#        'AZORES', 'BAHAMAS', 'BANGLADESH', 'BARBADOS', 'BAY OF BENGAL',
#        'BELIZE', 'BERMUDA', 'BRAZIL', 'BRITISH ISLES',
#        'BRITISH NEW GUINEA', 'BRITISH VIRGIN ISLANDS',
#        'BRITISH WEST INDIES', 'BURMA', 'CANADA', 'CAPE VERDE',
#        'CARIBBEAN SEA', 'CAYMAN ISLANDS', 'CENTRAL PACIFIC', 'CEYLON',
#        'CHILE', 'CHINA', 'COLUMBIA', 'COMOROS', 'COOK ISLANDS',
#        'COSTA RICA', 'CRETE', 'CROATIA', 'CUBA', 'CURACAO', 'CYPRUS',
#        'Coast of AFRICA', 'DIEGO GARCIA', 'DOMINICAN REPUBLIC', 'ECUADOR',
#        'EGYPT', 'EGYPT / ISRAEL', 'EL SALVADOR', 'ENGLAND',
#        'EQUATORIAL GUINEA / CAMEROON', 'FALKLAND ISLANDS',
#        'FEDERATED STATES OF MICRONESIA', 'FIJI', 'FRANCE',
#        'FRENCH POLYNESIA', 'Fiji', 'GABON', 'GEORGIA', 'GHANA',
# ...

# %%
#Como tem países que a escrita está em lowecase, passaremos tudo para uppercase.
shark_attack['Country'] = shark_attack['Country'].str.upper()

# %%
#Check se a condição foi aplicada
shark_attack['Country'].unique()
#Podemos anlisar que todos os nomes estão em uppercase.
# Out:
# array(['ADMIRALTY ISLANDS', 'AFRICA', 'ALGERIA', 'AMERICAN SAMOA',
#        'ANDAMAN / NICOBAR ISLANDAS', 'ANDAMAN ISLANDS', 'ANGOLA',
#        'ANTIGUA', 'ARGENTINA', 'ARUBA', 'ATLANTIC OCEAN', 'AUSTRALIA',
#        'AZORES', 'BAHAMAS', 'BANGLADESH', 'BARBADOS', 'BAY OF BENGAL',
#        'BELIZE', 'BERMUDA', 'BRAZIL', 'BRITISH ISLES',
#        'BRITISH NEW GUINEA', 'BRITISH VIRGIN ISLANDS',
#        'BRITISH WEST INDIES', 'BURMA', 'CANADA', 'CAPE VERDE',
#        'CARIBBEAN SEA', 'CAYMAN ISLANDS', 'CENTRAL PACIFIC', 'CEYLON',
#        'CHILE', 'CHINA', 'COLUMBIA', 'COMOROS', 'COOK ISLANDS',
#        'COSTA RICA', 'CRETE', 'CROATIA', 'CUBA', 'CURACAO', 'CYPRUS',
#        'COAST OF AFRICA', 'DIEGO GARCIA', 'DOMINICAN REPUBLIC', 'ECUADOR',
#        'EGYPT', 'EGYPT / ISRAEL', 'EL SALVADOR', 'ENGLAND',
#        'EQUATORIAL GUINEA / CAMEROON', 'FALKLAND ISLANDS',
#        'FEDERATED STATES OF MICRONESIA', 'FIJI', 'FRANCE',
# ...

# %% [markdown]
# # Atribuição de contininete nos países.

# %%
# Nesse passo, faremos de maneira manul a atribuição de continentes de cada país.
country_to_continent = {
    'USA': 'AMERICA',
    'AFRICA': 'AFRICA',
    'AUSTRALIA': 'OCEANIA',
    'NEW CALEDONIA': 'OCEANIA',
    'REUNION': 'AFRICA',
    'BAHAMAS': 'AMERICA',
    'SPAIN': 'EUROPA',
    'CHINA': 'ASIA',
    'JAPAN': 'ASIA',
    'COLUMBIA': 'AMERICA',
    'SOUTH AFRICA': 'AMERICA',
    'EGYPT': 'AFRICA',
    'NEW ZEALAND': 'OCEANIA',
    'INDONESIA': 'ASIA',
    'FRENCH POLYNESIA': 'OCEANIA',
    'CAPE VERDE': 'AFRICA',
    'BRAZIL': 'AMERICA',
    'DOMINICAN REPUBLIC': 'AMERICA',
    'CAYMAN ISLANDS': 'AMERICA',
    'UNITED ARAB EMIRATES': 'ASIA',
    'ARUBA': 'AMERICA',
    'MOZAMBIQUE': 'AFRICA',
    'THAILAND': 'ASIA',
    'FIJI': 'ASIA',
    'PUERTO RICO': 'AMERICA',
    'ITALY': 'EUROPA',
    'MEXICO': 'AMERICA',
    'GREECE': 'EUROPA',
    'MAURITIUS': 'AFRICA',
    'ST. MARTIN': 'AMERICA',
    'FRANCE': 'EUROPA',
    'ECUADOR': 'AMERICA',
    'PAPUA NEW GUINEA': 'OCEANIA',
    'TRINIDAD & TOBAGO': 'AMERICA',
    'KIRIBATI': 'OCEANIA',
    'ISRAEL': 'EUROPA',
    'TAIWAN': 'ASIA',
    'JAMAICA': 'AMERICA',
    'PALESTINIAN TERRITORIES': 'ASIA',
    'GUAM': 'OCEANIA',
    'SEYCHELLES': 'AFRICA',
    'BELIZE': 'AMERICA',
    'PHILIPPINES': 'ASIA',
    'NIGERIA': 'AFRICA',
    'TONGA': 'OCEANIA',
    'SCOTLAND': 'EUROPA',
    'CANADA': 'AMERICA',
    'CROATIA': 'EUROPA',
    'SAUDI ARABIA': 'ASIA',
    'CHILE': 'AMERICA',
    'ANTIGUA': 'AMERICA',
    'KENYA': 'AFRICA',
    'RUSSIA': 'EUROPA',
    'TURKS & CAICOS': 'AMERICA',
    'COSTA RICA': 'AMERICA',
    'UNITED KINGDOM': 'EUROPA',
    'MALAYSIA': 'ASIA',
    'UNITED ARAB EMIRATES (UAE)': 'ASIA',
    'SAMOA': 'OCEANIA', 
    'AZORES': 'EUROPA', 
    'SOLOMON ISLANDS': 'OCEANIA', 
    'SOUTH KOREA': 'ASIA', 
    'MALTA': 'EUROPA',
    'VIETNAM': 'ASIA', 
    'MADAGASCAR': 'AFRICA', 
    'PANAMA': 'AMERICA', 
    'SOMALIA': 'AFRICA', 
    'NEVIS': 'AMERICA', 
    'CUBA': 'AMERICA',
    'ENGLAND': 'EUROPA', 
    'BRITISH VIRGIN ISLANDS': 'AMERICA', 
    'NORWAY': 'EUROPA', 
    'SENEGAL': 'AFRICA', 
    'YEMEN': 'ASIA', 
    'SIERRA LEONE': 'AFRICA', 
    'ST. MAARTIN': 'AMERICA', 
    'GRAND CAYMAN': 'AMERICA',
    'SEYCHELLES': 'AFRICA', 
    'LIBERIA': 'AFRICA', 
    'VANUATU': 'OCEANIA', 
    'MEXICO ': 'AMERICA', 
    'HONDURAS': 'AMERICA',
    'VENEZUELA': 'AMERICA',
    'SRI LANKA': 'ASIA',
    'TONGA': 'OCEANIA',
    'URUGUAY': 'AMERICA',
    'INDIA': 'ASIA',
    'MICRONESIA': 'OCEANIA', 
    'CARIBBEAN SEA': 'AMERICA', 
    'OKINAWA': 'ASIA', 
    'TANZANIA': 'AFRICA',
    'MARSHALL ISLANDS': 'OCEANIA',  
    'NORTHERN ARABIAN SEA': 'ASIA',
    'HONG KONG': 'ASIA', 
    'EL SALVADOR': 'AMERICA', 
    'ANGOLA': 'AFRICA', 
    'BERMUDA': 'AMERICA', 
    'MONTENEGRO': 'EUROPA',
    'IRAN': 'ASIA', 
    'TUNISIA': 'AFRICA', 
    'NAMIBIA': 'AFRICA', 
    'NORTH ATLANTIC OCEAN': 'ASIA', 
    'PORTUGAL': 'EUROPA',
    'SOUTH CHINA SEA': 'ASIA', 
    'BANGLADESH': 'ASIA', 
    'PALAU': 'OCEANIA', 
    'WESTERN SAMOA': 'OCEANIA',
    'PACIFIC OCEAN ': 'OCEANIA', 
    'BRITISH ISLES': 'EUROPA',
    'GRENADA': 'AMERICA', 
    'IRAQ': 'ASIA', 
    'TURKEY': 'EUROPA',
    'SINGAPORE': 'ASIA', 
    'NEW BRITAIN': 'AMERICA', 
    'SUDAN': 'AFRICA', 
    'JOHNSTON ISLAND': 'AMERICA',
    'SOUTH PACIFIC OCEAN': 'OCEANIA', 
    'NEW GUINEA': 'OCEANIA',  
    'FEDERATED STATES OF MICRONESIA': 'OCEANIA',
    'ADMIRALTY ISLANDS': 'OCEANIA',  
    'PERSIAN GULF': 'ASIA', 
    'PACIFIC OCEAN': 'OCEANIA', 
    'NORTH SEA': 'EUROPA', 
    'NICARAGUA ': 'AMERICA', 
    'MALDIVE ISLANDS': 'ASIA',
    'AMERICAN SAMOA': 'OCEANIA', 
    'ANDAMAN / NICOBAR ISLANDAS': 'ASIA', 
    'GABON': 'AFRICA', 
    'MAYOTTE': 'AFRICA',
    'NORTH ATLANTIC OCEAN ': 'EUROPA', 
    'THE BALKANS': 'EUROPA', 
    'SUDAN': 'AFRICA', 
    'ARGENTINA': 'AMERICA',
    'MARTINIQUE': 'AMERICA', 
    'GUATEMALA': 'AMERICA', 
    'NETHERLANDS ANTILLES': 'AMERICA',
    'NORTHERN MARIANA ISLANDS': 'OCEANIA', 
    'IRAN / IRAQ': 'ASIA', 
    'JAVA': 'ASIA', 
    'SIERRA LEONE': 'AFRICA',
    'PHILIPPINES': 'ASIA', 
    'NICARAGUA': 'AMERICA', 
    'CENTRAL PACIFIC': 'AMERICA',
    'SOLOMON ISLANDS / VANUATU': 'OCEANIA',
    'BAY OF BENGAL': 'ASIA',
    'SLOVENIA': 'EUROPA',
    'CURACAO': 'AMERICA',
    'ITALY / CROATIA': 'EUROPA',
    'BARBADOS': 'AMERICA',
    'MONACO': 'EUROPA',
    'GUYANA': 'AMERICA',
    'HAITI': 'AMERICA',
    'SAN DOMINGO': 'AMERICA',
    'IRELAND': 'EUROPA',
    'KUWAIT': 'ASIA',
    'LIBYA': 'AFRICA',
    'YEMEN ': 'ASIA',
    'FALKLAND ISLANDS': 'AMERICA',
    'CRETE': 'EUROPA',
    'CYPRUS': 'EUROPA',
    'EGYPT ': 'AFRICA',
    'BURMA': 'ASIA',
    'LEBANON': 'ASIA',
    'PARAGUAY': 'AMERICA',
    'BRITISH NEW GUINEA': 'OCEANIA',
    'SYRIA': 'ASIA',
    'TUVALU': 'OCEANIA',
    'GUINEA': 'AFRICA',
    'EQUATORIAL GUINEA / CAMEROON': 'AFRICA',
    'COOK ISLANDS': 'OCEANIA',
    'ALGERIA': 'AFRICA',
    'COAST OF AFRICA': 'AFRICA',
    'TASMAN SEA': 'OCEANIA',
    'GHANA': 'AFRICA',
    'ST HELENA': 'AFRICA',
    'GREENLAND': 'AMERICA',
    'SWEDEN': 'EUROPA',
    'ICELAND': 'EUROPA',
    'DJIBOUTI': 'AFRICA',
    'BAHREIN': 'ASIA',
    'KOREA': 'ASIA',
    'ASIA': 'ASIA',
    'CEYLON (SRI LANKA)': 'ASIA'
}

# %%
#Com a função map, atribuiremos o continente para seus respectivos paises
shark_attack['Continent'] = shark_attack['Country'].map(country_to_continent)

# %%
#Check se a condição foi aplicada
shark_attack
# Out:
#        Case Number                  Date    Year          Type  \
# 3786    1962.10.15           15-Oct-1962  1962.0    Unprovoked
# 6049  1846.09.30.R  Reported 30-Sep-1846  1846.0    Unprovoked
# 6058  1844.07.16.R          1844.07.16.R  1844.0    Unprovoked
# 4286    1955.08.08           08-Aug-1955  1955.0    Unprovoked
# 4131    1958.12.12           12-Dec-1958  1958.0    Unprovoked
# ...            ...                   ...     ...           ...
# 5473    1906.08.20           20-Aug-1906  1906.0    Unprovoked
# 5611    1897.06.09           09-Jun-1897  1897.0  Sea Disaster
# 5603  1898.00.00.a        Summer of 1898  1898.0    Unprovoked
# 5547  1901.06.29.R  Reported 29-Jun-1901  1901.0       Invalid
# 5591    1898.07.15           15-Jul-1898  1898.0    Unprovoked
#
#                 Country             Area                      Location  \
# 3786  ADMIRALTY ISLANDS     Manus Island  Sisi  (west coast of island)
# ...

# %%
#Apliquei o value_counts para saber quantos paises tem em cada continente.
shark_attack['Continent'].value_counts()
# Out:
# AMERICA    3344
# OCEANIA    1788
# ASIA        385
# EUROPA      262
# AFRICA      238
# Name: Continent, dtype: int64

# %%
#Apliquei o value_counts(nomalize = True), para descobrir a porcentagem de ataques por continente.
shark_attack['Continent'].value_counts(normalize = True)
# Out:
# AMERICA    0.555759
# OCEANIA    0.297158
# ASIA       0.063985
# EUROPA     0.043543
# AFRICA     0.039555
# Name: Continent, dtype: float64

# %%
#Usei o normalize para ver a procentagem de fatalidades por ataque.
shark_attack['Fatal (Y/N)'].value_counts(normalize = True)
# Out:
# N          0.689936
# Y          0.212527
# UNKNOWN    0.097537
# Name: Fatal (Y/N), dtype: float64

# %%
#Fiz um novo groupby com a coluna  Fatal (Y/N) para poder avaliar o índice por continente.
result2 = shark_attack.groupby(['Continent','Fatal (Y/N)'])
result2.size()
# Out:
# Continent  Fatal (Y/N)
# AFRICA     N               107
#            UNKNOWN          20
#            Y               111
# AMERICA    N              2542
#            UNKNOWN         327
#            Y               475
# ASIA       N               181
#            UNKNOWN          27
#            Y               177
# EUROPA     N               145
#            UNKNOWN          54
#            Y                63
# OCEANIA    N              1203
#            UNKNOWN         159
#            Y               426
# dtype: int64

# %% [markdown]
# ## Plot Continent, Fatal

# %%
result2.size().plot.bar()
# Out:
# <AxesSubplot:xlabel='Continent,Fatal (Y/N)'>

# %% [markdown]
# # Atribui um valor em uma nova coluna chamada TOTAL e um valor em uma coluna nova chamada Percent para obter registros de cada continente.

# %% [markdown]
# ## África

# %%
shark_attack['Total'] = 1
africa_shark = shark_attack[shark_attack['Continent'] == 'AFRICA']
Africa  = africa_shark.groupby(['Continent', 'Fatal (Y/N)']).count()[["Total"]]
#Atribuição da porcentagem
Africa['Percent'] = Africa['Total']/sum(Africa['Total'])*100

Africa
#A Africa é o continente com menor índice de ataques de tubarão, porém o índice de mortalidade é o mais alto comparado a quantidade de ataques.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# AFRICA    N              107  44.957983
#           UNKNOWN         20   8.403361
#           Y              111  46.638655

# %% [markdown]
# ## América

# %%
america_shark = shark_attack[shark_attack['Continent'] == 'AMERICA']
America  = america_shark.groupby(['Continent', 'Fatal (Y/N)']).count()[["Total"]]
#Atribuição da porcentagem
America['Percent'] = America['Total']/sum(America['Total'])*100

America
#Podemos analisar que a America teve um grande índice de ataques de tubarão, porém a grande maioria não foi faltal.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# AMERICA   N             2542  76.016746
#           UNKNOWN        327   9.778708
#           Y              475  14.204545

# %% [markdown]
# ## Oceania

# %%
oceania_shark = shark_attack[shark_attack['Continent'] == 'OCEANIA']
Oceania  = oceania_shark.groupby(['Continent', 'Fatal (Y/N)']).count()[["Total"]]
#Atribuição da porcentagem
Oceania['Percent'] = Oceania['Total']/sum(Oceania['Total'])*100
Oceania
#A Oceania ficou em segundo lugar comparado a quantidade de ataques de tubarão, porém o índice de mortalidade é baixo comparado a quantidade de ataques.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# OCEANIA   N             1203  67.281879
#           UNKNOWN        159   8.892617
#           Y              426  23.825503

# %% [markdown]
# ## Ásia

# %%
asia_shark = shark_attack[shark_attack['Continent'] == 'ASIA']
Asia  = asia_shark.groupby(['Continent', 'Fatal (Y/N)']).count()[["Total"]]
#Atribuição da porcentagem
Asia['Percent'] = Asia['Total']/sum(Asia['Total'])*100
Asia
#A Asia fica em segundo lugar com um índice alto de mortalidade comparado a quantidade de ataques de tubarão.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# ASIA      N              181  47.012987
#           UNKNOWN         27   7.012987
#           Y              177  45.974026

# %% [markdown]
# ## Europa

# %%
europa_shark = shark_attack[shark_attack['Continent'] == 'EUROPA']
Europa  = europa_shark.groupby(['Continent', 'Fatal (Y/N)']).count()[["Total"]]
#Atribuição da porcentagem
Europa['Percent'] = Europa['Total']/sum(Europa['Total'])*100
Europa
#A Europa tem o segundo menor índice de ataques de tubarão e um baixo índice de taxa de mortalidade.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# EUROPA    N              145  55.343511
#           UNKNOWN         54  20.610687
#           Y               63  24.045802

# %% [markdown]
# # Concatenação dos DataFrames dos continentes.

# %%
#Concatenação dos DataFrames para melhor vizualização dos dados.
shark_final = pd.concat([Europa,Asia, Oceania, America, Africa])
shark_final#.reset_index() #use o .reset_index() para facilitar o trabalho futuro caso precise alterar algo no DataFrame.
# Out:
#                        Total    Percent
# Continent Fatal (Y/N)
# EUROPA    N              145  55.343511
#           UNKNOWN         54  20.610687
#           Y               63  24.045802
# ASIA      N              181  47.012987
#           UNKNOWN         27   7.012987
#           Y              177  45.974026
# OCEANIA   N             1203  67.281879
#           UNKNOWN        159   8.892617
#           Y              426  23.825503
# AMERICA   N             2542  76.016746
#           UNKNOWN        327   9.778708
#           Y              475  14.204545
# AFRICA    N              107  44.957983
#           UNKNOWN         20   8.403361
#           Y              111  46.638655

# %%
import matplotlib.pyplot as plt

# %%
#Usei o plot.bar para ter uma melhor visualização 
shark_final.plot.bar()

# %% [markdown]
# # Exportingo to csv

# %%
pwd
# Out:
# 'C:\\Users\\Matheus Zavagli\\Projeto-Shark-Attack'

# %%
data = data.to_csv('vehicles/vehicles.csv', index=False)
